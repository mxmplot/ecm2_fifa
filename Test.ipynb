# %%
import pandas as pd
from sklearn.linear_model import LassoCV
from statsmodels.tools import add_constant

def read_data(group_name):
    file_path = f"C:/Users/koala/Documents/МГУ/6 семестр/Untitled Folder/new/{group_name}/{group_name}_group_all_seasons_dummy_updated_new.csv"
    return pd.read_csv(file_path, index_col=['id', 'Season'])

def build_lasso_regression(df, target, features):
    X = add_constant(df[features])  # Add constant to the features
    y = df[target]
    lasso = LassoCV(cv=5, random_state=42).fit(X, y)
    return lasso

group_names = ['red', 'yellow', 'green']
regressors = {
    'red': ['Age', 'Age^2', 'Gls', 'SoT%', 'Cmp%', 'Ast', 'Tkl%', 'Clr', 'Att.5', 'Succ%', 'PPM', 'CrdY', 'CrdR', 'Won%', 'def', 'mid', 'forw'],
    'yellow': ['Age', 'xG', 'Blocks', 'Tkl+Int', 'Err', 'Def Pen', 'Att.5', 'Succ%', 'Mn/Sub', 'xG+/-90', 'OG', 'Won%', 'def', 'mid', 'forw', 'Age^2'],
    'green': ['Age', 'Sh/90', 'np:G-xG', 'Dist', 'npxG/Sh', 'Cmp%', 'A-xAG', 'Crs', 'TO', 'Tkl%', 'Tkl+Int', 'Err', 'Def Pen', 'Succ%', '44986', 'onGA', 'xG+/-90', 'CrdY', 'CrdR', 'Won%', 'def', 'mid', 'forw', 'Age^2']
}

lasso_models = {}

for group_name in group_names:
    df = read_data(group_name)
    lasso_model = build_lasso_regression(df, 'RATING', regressors[group_name])
    lasso_models[group_name] = lasso_model

    print(f"\nLasso Regression Results for {group_name} group:")
    coef_df = pd.DataFrame(lasso_model.coef_, index=['const'] + regressors[group_name], columns=['Coefficient'])
    coef_df = coef_df[coef_df['Coefficient'] != 0]  # Filter out zero coefficients
    print(coef_df)
# Out:
# Lasso Regression Results for red group:
#        Coefficient
# Age^2     0.004797
# Gls       0.272159
# SoT%      0.005942
# Cmp%      0.123940
# Ast       0.315364
# Tkl%     -0.007367
# Clr       0.015809
# Att.5     0.024235
# Succ%     0.007319
# PPM       2.645793
# CrdY      0.018055
# Won%      0.007446
#
# Lasso Regression Results for yellow group:
#          Coefficient
# xG          0.337470
# Blocks      0.009266
# Tkl+Int     0.014493
# Err         0.017769
# Def Pen     0.009102
# Att.5       0.025955
# Succ%       0.015606
# Mn/Sub     -0.001260
# xG+/-90     2.393429
# Won%        0.002479
# Age^2       0.005079
#
# Lasso Regression Results for green group:
#          Coefficient
# Sh/90       0.663461
# np:G-xG     0.244772
# Dist       -0.080479
# Cmp%        0.109724
# A-xAG       0.114243
# Crs         0.011196
# TO          0.248788
# Tkl%       -0.018398
# Tkl+Int     0.016514
# Def Pen     0.009428
# Succ%       0.001857
# 44986       0.019125
# onGA       -0.031843
# xG+/-90     1.527393
# Won%        0.004809
# Age^2       0.005346

# %%
import pandas as pd
from linearmodels import PanelOLS, RandomEffects
from statsmodels.tools.tools import add_constant
from linearmodels.panel import compare

def build_fixed_effects_regression(df, target, features):
    X = add_constant(df[features])
    y = df[target]
    fixed_effects_mod = PanelOLS(y, X, entity_effects=True, time_effects=True, drop_absorbed=True, check_rank=False)
    fixed_effects_res = fixed_effects_mod.fit()
    return fixed_effects_res

def build_random_effects_regression(df, target, features):
    X = add_constant(df[features])
    y = df[target]
    random_effects_mod = RandomEffects(y, X, check_rank=False)
    random_effects_res = random_effects_mod.fit()
    return random_effects_res

group_names = ['red', 'yellow', 'green']
regressors = {
    'red': ['Gls', 'SoT%', 'Cmp%', 'Ast', 'Tkl%', 'Clr', 'Att.5', 'Succ%', 'PPM', 'CrdY', 'CrdR', 'Won%', 'def', 'mid', 'forw'],
    'yellow': ['xG', 'Blocks', 'Tkl+Int', 'Err', 'Def Pen', 'Att.5', 'Succ%', 'Mn/Sub', 'xG+/-90', 'OG', 'Won%', 'def', 'mid', 'forw'],
    'green': ['Sh/90', 'np:G-xG', 'Dist', 'npxG/Sh', 'Cmp%', 'A-xAG', 'Crs', 'TO', 'Tkl%', 'Tkl+Int', 'Err', 'Def Pen', 'Succ%', '44986', 'onGA', 'xG+/-90', 'CrdY', 'CrdR', 'Won%', 'def', 'mid', 'forw']
}

for group_name in group_names:
    df = read_data(group_name)
    
    fixed_effects_res = build_fixed_effects_regression(df, 'RATING', regressors[group_name])
    random_effects_res = build_random_effects_regression(df, 'RATING', regressors[group_name])

    print(f"\nFixed Effects Regression Results for {group_name} group:")
    print(fixed_effects_res)

    print(f"\nRandom Effects Regression Results for {group_name} group:")
    print(random_effects_res)
    
    print(compare({'FE':fixed_effects_res, 'RE' :random_effects_res }))
# Out:
# <ipython-input-9-e364ec12fab5>:10: AbsorbingEffectWarning:
# Variables have been fully absorbed and have removed from the regression:
#
# forw
#
#   fixed_effects_res = fixed_effects_mod.fit()
# Fixed Effects Regression Results for red group:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.2687
# Estimator:                   PanelOLS   R-squared (Between):              0.3722
# No. Observations:                2464   R-squared (Within):               0.2606
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.3587
# Time:                        21:18:54   Log-likelihood                   -4258.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      48.047
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(14,1831)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             48.047
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(14,1831)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          72.624     0.8044     90.287     0.0000      71.047      74.202
# Gls            0.1403     0.0157     8.9106     0.0000      0.1094      0.1712
# SoT%           0.0038     0.0024     1.5812     0.1140     -0.0009      0.0086
# Cmp%           0.0196     0.0101     1.9476     0.0516     -0.0001      0.0393
# Ast            0.1213     0.0210     5.7873     0.0000      0.0802      0.1624
# Tkl%          -0.0008     0.0027    -0.2798     0.7797     -0.0061      0.0045
# Clr            0.0120     0.0017     6.8500     0.0000      0.0085      0.0154
# Att.5          0.0154     0.0024     6.4569     0.0000      0.0107      0.0201
# Succ%         -0.0009     0.0023    -0.3867     0.6990     -0.0053      0.0036
# PPM            1.1476     0.1094     10.486     0.0000      0.9330      1.3622
# CrdY           0.0441     0.0196     2.2527     0.0244      0.0057      0.0825
# CrdR           0.0087     0.0887     0.0977     0.9222     -0.1652      0.1826
# Won%           0.0044     0.0034     1.3013     0.1933     -0.0022      0.0111
# def            0.0877     0.2323     0.3774     0.7059     -0.3679      0.5432
# mid            0.2215     0.1464     1.5126     0.1306     -0.0657      0.5086
# ==============================================================================
#
# F-test for Poolability: 11.348
# P-value: 0.0000
# Distribution: F(618,1831)
#
# Included effects: Entity, Time
#
# Random Effects Regression Results for red group:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.3602
# Estimator:              RandomEffects   R-squared (Between):              0.5292
# No. Observations:                2464   R-squared (Within):               0.2003
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.4894
# Time:                        21:18:56   Log-likelihood                   -4942.0
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      91.868
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(15,2448)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             95.784
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(15,2448)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          50.249   1.73e+06  2.905e-05     1.0000  -3.391e+06   3.392e+06
# Gls            0.2070     0.0158     13.114     0.0000      0.1761      0.2380
# SoT%           0.0033     0.0027     1.2141     0.2248     -0.0020      0.0085
# Cmp%           0.0717     0.0092     7.8224     0.0000      0.0537      0.0897
# Ast            0.1883     0.0226     8.3456     0.0000      0.1441      0.2325
# Tkl%          -0.0026     0.0030    -0.8787     0.3796     -0.0084      0.0032
# Clr            0.0124     0.0017     7.1821     0.0000      0.0090      0.0158
# Att.5          0.0169     0.0023     7.3237     0.0000      0.0124      0.0214
# Succ%      -2.838e-05     0.0025    -0.0115     0.9908     -0.0049      0.0048
# PPM            1.8771     0.1155     16.247     0.0000      1.6505      2.1036
# CrdY           0.0510     0.0204     2.4984     0.0125      0.0110      0.0911
# CrdR           0.0193     0.0985     0.1960     0.8446     -0.1738      0.2124
# Won%           0.0057     0.0036     1.5767     0.1150     -0.0014      0.0127
# def            16.531   1.73e+06  9.558e-06     1.0000  -3.392e+06   3.392e+06
# mid            16.970   1.73e+06  9.812e-06     1.0000  -3.392e+06   3.392e+06
# forw           16.747   1.73e+06  9.683e-06     1.0000  -3.392e+06   3.392e+06
# ==============================================================================
#                     Model Comparison
# ========================================================
#                                     FE                RE
# --------------------------------------------------------
# Dep. Variable                   RATING            RATING
# Estimator                     PanelOLS     RandomEffects
# No. Observations                  2464              2464
# Cov. Est.                   Unadjusted        Unadjusted
# R-squared                       0.2687            0.3602
# R-Squared (Within)              0.2606            0.2003
# R-Squared (Between)             0.3722            0.5292
# R-Squared (Overall)             0.3587            0.4894
# F-statistic                     48.047            91.868
# P-value (F-stat)                0.0000            0.0000
# =====================     ============   ===============
# const                           72.624            50.249
#                               (90.287)       (2.905e-05)
# Gls                             0.1403            0.2070
#                               (8.9106)          (13.114)
# SoT%                            0.0038            0.0033
#                               (1.5812)          (1.2141)
# Cmp%                            0.0196            0.0717
#                               (1.9476)          (7.8224)
# Ast                             0.1213            0.1883
#                               (5.7873)          (8.3456)
# Tkl%                           -0.0008           -0.0026
#                              (-0.2798)         (-0.8787)
# Clr                             0.0120            0.0124
#                               (6.8500)          (7.1821)
# Att.5                           0.0154            0.0169
#                               (6.4569)          (7.3237)
# Succ%                          -0.0009        -2.838e-05
#                              (-0.3867)         (-0.0115)
# PPM                             1.1476            1.8771
#                               (10.486)          (16.247)
# CrdY                            0.0441            0.0510
#                               (2.2527)          (2.4984)
# CrdR                            0.0087            0.0193
#                               (0.0977)          (0.1960)
# Won%                            0.0044            0.0057
#                               (1.3013)          (1.5767)
# def                             0.0877            16.531
#                               (0.3774)       (9.558e-06)
# mid                             0.2215            16.970
#                               (1.5126)       (9.812e-06)
# forw                                              16.747
#                                              (9.683e-06)
# ======================= ============== =================
# Effects                         Entity
#                                   Time
# --------------------------------------------------------
#
# T-stats reported in parentheses
# Fixed Effects Regression Results for yellow group:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.2190
# Estimator:                   PanelOLS   R-squared (Between):              0.2759
# No. Observations:                2464   R-squared (Within):               0.2106
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.2680
# Time:                        21:19:00   Log-likelihood                   -4339.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      39.515
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(13,1832)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             39.515
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(13,1832)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          75.696     0.2475     305.86     0.0000      75.211      76.182
# xG             0.2099     0.0225     9.3245     0.0000      0.1657      0.2540
# Blocks         0.0118     0.0058     2.0376     0.0417      0.0004      0.0232
# Tkl+Int        0.0120     0.0025     4.8769     0.0000      0.0072      0.0169
# Err            0.0355     0.0477     0.7448     0.4565     -0.0580      0.1290
# Def Pen        0.0034     0.0015     2.3281     0.0200      0.0005      0.0062
# Att.5          0.0091     0.0028     3.2508     0.0012      0.0036      0.0146
# Succ%          0.0001     0.0023     0.0586     0.9533     -0.0044      0.0047
# Mn/Sub        -0.0029     0.0032    -0.9112     0.3623     -0.0092      0.0034
# xG+/-90        0.4657     0.0778     5.9885     0.0000      0.3132      0.6182
# OG            -0.0729     0.1486    -0.4904     0.6239     -0.3644      0.2186
# Won%           0.0046     0.0035     1.3164     0.1882     -0.0023      0.0115
# def            0.3827     0.2396     1.5974     0.1103     -0.0872      0.8525
# mid            0.1438     0.1511     0.9518     0.3413     -0.1525      0.4402
# ==============================================================================
#
# F-test for Poolability: 13.353
# P-value: 0.0000
# Distribution: F(618,1832)
#
# Included effects: Entity, Time
#
# Random Effects Regression Results for yellow group:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.2732
# Estimator:              RandomEffects   R-squared (Between):              0.4018
# No. Observations:                2464   R-squared (Within):               0.1743
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.3743
# Time:                        21:19:06   Log-likelihood                   -4981.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      65.748
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(14,2449)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             48.196
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(14,2449)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          56.350
# xG             0.2994     0.0211     14.210     0.0000      0.2581      0.3407
# Blocks         0.0092     0.0058     1.5885     0.1123     -0.0022      0.0205
# Tkl+Int        0.0088     0.0024     3.6383     0.0003      0.0041      0.0136
# Err            0.0899     0.0523     1.7198     0.0856     -0.0126      0.1925
# Def Pen        0.0063     0.0014     4.4770     0.0000      0.0036      0.0091
# Att.5          0.0133     0.0027     4.9285     0.0000      0.0080      0.0186
# Succ%          0.0012     0.0025     0.4821     0.6298     -0.0037      0.0061
# Mn/Sub         0.0065     0.0031     2.0966     0.0361      0.0004      0.0125
# xG+/-90        1.0392     0.0806     12.888     0.0000      0.8811      1.1973
# OG            -0.0699     0.1634    -0.4275     0.6690     -0.3902      0.2505
# Won%           0.0043     0.0037     1.1619     0.2454     -0.0030      0.0116
# def            18.825
# mid            18.910
# forw           18.616
# ==============================================================================
#                     Model Comparison
# ========================================================
#                                     FE                RE
# --------------------------------------------------------
# Dep. Variable                   RATING            RATING
# Estimator                     PanelOLS     RandomEffects
# No. Observations                  2464              2464
# Cov. Est.                   Unadjusted        Unadjusted
# R-squared                       0.2190            0.2732
# R-Squared (Within)              0.2106            0.1743
# R-Squared (Between)             0.2759            0.4018
# R-Squared (Overall)             0.2680            0.3743
# F-statistic                     39.515            65.748
# P-value (F-stat)                0.0000            0.0000
# =====================     ============   ===============
# const                           75.696            56.350
#                               (305.86)
# xG                              0.2099            0.2994
#                               (9.3245)          (14.210)
# Blocks                          0.0118            0.0092
#                               (2.0376)          (1.5885)
# Tkl+Int                         0.0120            0.0088
#                               (4.8769)          (3.6383)
# Err                             0.0355            0.0899
#                               (0.7448)          (1.7198)
# Def Pen                         0.0034            0.0063
#                               (2.3281)          (4.4770)
# Att.5                           0.0091            0.0133
#                               (3.2508)          (4.9285)
# Succ%                           0.0001            0.0012
#                               (0.0586)          (0.4821)
# Mn/Sub                         -0.0029            0.0065
#                              (-0.9112)          (2.0966)
# xG+/-90                         0.4657            1.0392
#                               (5.9885)          (12.888)
# OG                             -0.0729           -0.0699
#                              (-0.4904)         (-0.4275)
# Won%                            0.0046            0.0043
#                               (1.3164)          (1.1619)
# def                             0.3827            18.825
#                               (1.5974)
# mid                             0.1438            18.910
#                               (0.9518)
# forw                                              18.616
#
# ======================= ============== =================
# Effects                         Entity
#                                   Time
# --------------------------------------------------------
#
# T-stats reported in parentheses
# Fixed Effects Regression Results for green group:
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.2209
# Estimator:                   PanelOLS   R-squared (Between):              0.2550
# No. Observations:                2464   R-squared (Within):               0.2156
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.2502
# Time:                        21:19:14   Log-likelihood                   -4336.9
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      24.621
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(21,1824)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             24.621
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(21,1824)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          73.281     0.9277     78.989     0.0000      71.462      75.101
# Sh/90          0.2299     0.0749     3.0716     0.0022      0.0831      0.3767
# np:G-xG        0.1693     0.0245     6.9102     0.0000      0.1212      0.2173
# Dist          -0.0171     0.0103    -1.6574     0.0976     -0.0373      0.0031
# npxG/Sh        3.3878     0.9993     3.3902     0.0007      1.4279      5.3476
# Cmp%           0.0339     0.0109     3.1073     0.0019      0.0125      0.0553
# A-xAG          0.1091     0.0280     3.8976     0.0001      0.0542      0.1640
# Crs            0.0101     0.0017     6.0529     0.0000      0.0068      0.0133
# TO             0.0840     0.0153     5.4900     0.0000      0.0540      0.1140
# Tkl%          -0.0038     0.0028    -1.3461     0.1784     -0.0094      0.0017
# Tkl+Int        0.0180     0.0026     6.8665     0.0000      0.0128      0.0231
# Err            0.0369     0.0479     0.7704     0.4412     -0.0570      0.1307
# Def Pen        0.0048     0.0015     3.1678     0.0016      0.0018      0.0079
# Succ%         -0.0004     0.0024    -0.1502     0.8806     -0.0050      0.0043
# 44986          0.0016     0.0014     1.2109     0.2261     -0.0010      0.0043
# onGA          -0.0133     0.0056    -2.3802     0.0174     -0.0242     -0.0023
# xG+/-90        0.2876     0.0882     3.2610     0.0011      0.1146      0.4606
# CrdY           0.0091     0.0217     0.4201     0.6745     -0.0335      0.0517
# CrdR          -0.0450     0.0919    -0.4893     0.6247     -0.2253      0.1353
# Won%           0.0045     0.0035     1.2759     0.2021     -0.0024      0.0114
# def            0.2347     0.2416     0.9718     0.3313     -0.2390      0.7085
# mid            0.1581     0.1518     1.0416     0.2977     -0.1396      0.4557
# ==============================================================================
#
# F-test for Poolability: 12.824
# P-value: 0.0000
# Distribution: F(618,1824)
#
# Included effects: Entity, Time
#
# Random Effects Regression Results for green group:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.2792
# Estimator:              RandomEffects   R-squared (Between):              0.4242
# No. Observations:                2464   R-squared (Within):               0.1634
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.3926
# Time:                        21:19:16   Log-likelihood                   -4991.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      42.968
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(22,2441)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             45.203
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(22,2441)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          52.096
# Sh/90          0.4682     0.0755     6.2051     0.0000      0.3202      0.6161
# np:G-xG        0.2119     0.0270     7.8628     0.0000      0.1591      0.2648
# Dist          -0.0345     0.0110    -3.1394     0.0017     -0.0561     -0.0130
# npxG/Sh        4.5987     1.0841     4.2419     0.0000      2.4728      6.7246
# Cmp%           0.0788     0.0102     7.6992     0.0000      0.0588      0.0989
# A-xAG          0.1399     0.0309     4.5300     0.0000      0.0793      0.2004
# Crs            0.0123     0.0016     7.6952     0.0000      0.0091      0.0154
# TO             0.1319     0.0155     8.5061     0.0000      0.1015      0.1623
# Tkl%          -0.0066     0.0031    -2.1286     0.0334     -0.0127     -0.0005
# Tkl+Int        0.0139     0.0025     5.4540     0.0000      0.0089      0.0189
# Err            0.0677     0.0527     1.2848     0.1990     -0.0356      0.1711
# Def Pen        0.0073     0.0015     4.8027     0.0000      0.0043      0.0103
# Succ%         -0.0006     0.0025    -0.2368     0.8128     -0.0056      0.0044
# 44986          0.0069     0.0012     5.6807     0.0000      0.0045      0.0093
# onGA          -0.0171     0.0059    -2.8961     0.0038     -0.0287     -0.0055
# xG+/-90        0.6587     0.0942     6.9949     0.0000      0.4740      0.8433
# CrdY           0.0045     0.0231     0.1946     0.8457     -0.0408      0.0497
# CrdR          -0.0312     0.1013    -0.3079     0.7582     -0.2299      0.1675
# Won%           0.0049     0.0037     1.3188     0.1874     -0.0024      0.0122
# def            17.142
# mid            17.495
# forw           17.458
# ==============================================================================
#                     Model Comparison
# ========================================================
#                                     FE                RE
# --------------------------------------------------------
# Dep. Variable                   RATING            RATING
# Estimator                     PanelOLS     RandomEffects
# No. Observations                  2464              2464
# Cov. Est.                   Unadjusted        Unadjusted
# R-squared                       0.2209            0.2792
# R-Squared (Within)              0.2156            0.1634
# R-Squared (Between)             0.2550            0.4242
# R-Squared (Overall)             0.2502            0.3926
# F-statistic                     24.621            42.968
# P-value (F-stat)                0.0000            0.0000
# =====================     ============   ===============
# const                           73.281            52.096
#                               (78.989)
# Sh/90                           0.2299            0.4682
#                               (3.0716)          (6.2051)
# np:G-xG                         0.1693            0.2119
#                               (6.9102)          (7.8628)
# Dist                           -0.0171           -0.0345
#                              (-1.6574)         (-3.1394)
# npxG/Sh                         3.3878            4.5987
#                               (3.3902)          (4.2419)
# Cmp%                            0.0339            0.0788
#                               (3.1073)          (7.6992)
# A-xAG                           0.1091            0.1399
#                               (3.8976)          (4.5300)
# Crs                             0.0101            0.0123
#                               (6.0529)          (7.6952)
# TO                              0.0840            0.1319
#                               (5.4900)          (8.5061)
# Tkl%                           -0.0038           -0.0066
#                              (-1.3461)         (-2.1286)
# Tkl+Int                         0.0180            0.0139
#                               (6.8665)          (5.4540)
# Err                             0.0369            0.0677
#                               (0.7704)          (1.2848)
# Def Pen                         0.0048            0.0073
#                               (3.1678)          (4.8027)
# Succ%                          -0.0004           -0.0006
#                              (-0.1502)         (-0.2368)
# 44986                           0.0016            0.0069
#                               (1.2109)          (5.6807)
# onGA                           -0.0133           -0.0171
#                              (-2.3802)         (-2.8961)
# xG+/-90                         0.2876            0.6587
#                               (3.2610)          (6.9949)
# CrdY                            0.0091            0.0045
#                               (0.4201)          (0.1946)
# CrdR                           -0.0450           -0.0312
#                              (-0.4893)         (-0.3079)
# Won%                            0.0045            0.0049
#                               (1.2759)          (1.3188)
# def                             0.2347            17.142
#                               (0.9718)
# mid                             0.1581            17.495
#                               (1.0416)
# forw                                              17.458
#
# ======================= ============== =================
# Effects                         Entity
#                                   Time
# --------------------------------------------------------
#
# T-stats reported in parentheses

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from linearmodels.panel import RandomEffects
from scipy.stats import shapiro


import numpy as np
from scipy import stats

def detect_outliers_z_score(data, threshold=3):
    z_scores = np.abs(stats.zscore(data))
    outliers = np.where(z_scores > threshold)
    return outliers

for group_name in group_names:
    df = read_data(group_name)
    random_effects_res = build_random_effects_regression(df, 'RATING', regressors[group_name])

    print(f"\nRandom Effects Regression Results for {group_name} group:")
    print(random_effects_res)

    residuals = random_effects_res.resids
    outliers = detect_outliers_z_score(residuals)

    print(f"\nOutliers detected for {group_name} group:")
    if len(outliers[0]) > 0:
        print(f"Indices: {outliers[0]}")
    else:
        print("No outliers detected")
# Out:
# Random Effects Regression Results for red group:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.3602
# Estimator:              RandomEffects   R-squared (Between):              0.5292
# No. Observations:                2464   R-squared (Within):               0.2003
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.4894
# Time:                        23:27:27   Log-likelihood                   -4942.0
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      91.868
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(15,2448)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             95.784
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(15,2448)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          50.249   1.73e+06  2.905e-05     1.0000  -3.391e+06   3.392e+06
# Gls            0.2070     0.0158     13.114     0.0000      0.1761      0.2380
# SoT%           0.0033     0.0027     1.2141     0.2248     -0.0020      0.0085
# Cmp%           0.0717     0.0092     7.8224     0.0000      0.0537      0.0897
# Ast            0.1883     0.0226     8.3456     0.0000      0.1441      0.2325
# Tkl%          -0.0026     0.0030    -0.8787     0.3796     -0.0084      0.0032
# Clr            0.0124     0.0017     7.1821     0.0000      0.0090      0.0158
# Att.5          0.0169     0.0023     7.3237     0.0000      0.0124      0.0214
# Succ%      -2.838e-05     0.0025    -0.0115     0.9908     -0.0049      0.0048
# PPM            1.8771     0.1155     16.247     0.0000      1.6505      2.1036
# CrdY           0.0510     0.0204     2.4984     0.0125      0.0110      0.0911
# CrdR           0.0193     0.0985     0.1960     0.8446     -0.1738      0.2124
# Won%           0.0057     0.0036     1.5767     0.1150     -0.0014      0.0127
# def            16.531   1.73e+06  9.558e-06     1.0000  -3.392e+06   3.392e+06
# mid            16.970   1.73e+06  9.812e-06     1.0000  -3.392e+06   3.392e+06
# forw           16.747   1.73e+06  9.683e-06     1.0000  -3.392e+06   3.392e+06
# ==============================================================================
#
# Outliers detected for red group:
# Indices: [  19   30   43   79   83  137  144  217  323  358  364  383  384  443
#   461  494  535  543  551  601  925 1521 2168 2431]
#
# Random Effects Regression Results for yellow group:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.2732
# Estimator:              RandomEffects   R-squared (Between):              0.4018
# No. Observations:                2464   R-squared (Within):               0.1743
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.3743
# Time:                        23:27:28   Log-likelihood                   -4981.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      65.748
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(14,2449)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             48.196
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(14,2449)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          56.350
# xG             0.2994     0.0211     14.210     0.0000      0.2581      0.3407
# Blocks         0.0092     0.0058     1.5885     0.1123     -0.0022      0.0205
# Tkl+Int        0.0088     0.0024     3.6383     0.0003      0.0041      0.0136
# Err            0.0899     0.0523     1.7198     0.0856     -0.0126      0.1925
# Def Pen        0.0063     0.0014     4.4770     0.0000      0.0036      0.0091
# Att.5          0.0133     0.0027     4.9285     0.0000      0.0080      0.0186
# Succ%          0.0012     0.0025     0.4821     0.6298     -0.0037      0.0061
# Mn/Sub         0.0065     0.0031     2.0966     0.0361      0.0004      0.0125
# xG+/-90        1.0392     0.0806     12.888     0.0000      0.8811      1.1973
# OG            -0.0699     0.1634    -0.4275     0.6690     -0.3902      0.2505
# Won%           0.0043     0.0037     1.1619     0.2454     -0.0030      0.0116
# def            18.825
# mid            18.910
# forw           18.616
# ==============================================================================
#
# Outliers detected for yellow group:
# Indices: [  19   79   89  137  144  217  222  323  383  384  461  494  507  551
#   980 1343 1490 1521]
#
# Random Effects Regression Results for green group:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.2792
# Estimator:              RandomEffects   R-squared (Between):              0.4242
# No. Observations:                2464   R-squared (Within):               0.1634
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.3926
# Time:                        23:27:29   Log-likelihood                   -4991.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      42.968
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(22,2441)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             45.203
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(22,2441)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          52.096
# Sh/90          0.4682     0.0755     6.2051     0.0000      0.3202      0.6161
# np:G-xG        0.2119     0.0270     7.8628     0.0000      0.1591      0.2648
# Dist          -0.0345     0.0110    -3.1394     0.0017     -0.0561     -0.0130
# npxG/Sh        4.5987     1.0841     4.2419     0.0000      2.4728      6.7246
# Cmp%           0.0788     0.0102     7.6992     0.0000      0.0588      0.0989
# A-xAG          0.1399     0.0309     4.5300     0.0000      0.0793      0.2004
# Crs            0.0123     0.0016     7.6952     0.0000      0.0091      0.0154
# TO             0.1319     0.0155     8.5061     0.0000      0.1015      0.1623
# Tkl%          -0.0066     0.0031    -2.1286     0.0334     -0.0127     -0.0005
# Tkl+Int        0.0139     0.0025     5.4540     0.0000      0.0089      0.0189
# Err            0.0677     0.0527     1.2848     0.1990     -0.0356      0.1711
# Def Pen        0.0073     0.0015     4.8027     0.0000      0.0043      0.0103
# Succ%         -0.0006     0.0025    -0.2368     0.8128     -0.0056      0.0044
# 44986          0.0069     0.0012     5.6807     0.0000      0.0045      0.0093
# onGA          -0.0171     0.0059    -2.8961     0.0038     -0.0287     -0.0055
# xG+/-90        0.6587     0.0942     6.9949     0.0000      0.4740      0.8433
# CrdY           0.0045     0.0231     0.1946     0.8457     -0.0408      0.0497
# CrdR          -0.0312     0.1013    -0.3079     0.7582     -0.2299      0.1675
# Won%           0.0049     0.0037     1.3188     0.1874     -0.0024      0.0122
# def            17.142
# mid            17.495
# forw           17.458
# ==============================================================================
#
# Outliers detected for green group:
# Indices: [  19   79   89  137  144  217  222  384  461  494  507  543  551  601
#   925  980 1343 1521 1959 2095]

# %%
import statsmodels.api as sm
from statsmodels.stats.diagnostic import het_breuschpagan

for group_name in group_names:
    df = read_data(group_name)
    random_effects_res = build_random_effects_regression(df, 'RATING', regressors[group_name])

    print(f"\nRandom Effects Regression Results for {group_name} group:")
    print(random_effects_res)

    # Conducting Breusch-Pagan test
    residuals = random_effects_res.resids
    X = df[regressors[group_name]]
    bp_test = het_breuschpagan(residuals, sm.add_constant(X))

    print(f"\nBreusch-Pagan test for {group_name} group:")
    print(f"LM statistic: {bp_test[0]}, p-value: {bp_test[1]}, f-value: {bp_test[2]}, f_p-value: {bp_test[3]}")

    # Checking for heteroskedasticity using a significance level of 0.05
    if bp_test[1] < 0.05:
        print(f"Heteroskedasticity detected for {group_name} group.")
    else:
        print(f"No heteroskedasticity detected for {group_name} group.")
# Out:
# Random Effects Regression Results for red group:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.3602
# Estimator:              RandomEffects   R-squared (Between):              0.5292
# No. Observations:                2464   R-squared (Within):               0.2003
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.4894
# Time:                        23:30:50   Log-likelihood                   -4942.0
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      91.868
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(15,2448)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             95.784
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(15,2448)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          50.249   1.73e+06  2.905e-05     1.0000  -3.391e+06   3.392e+06
# Gls            0.2070     0.0158     13.114     0.0000      0.1761      0.2380
# SoT%           0.0033     0.0027     1.2141     0.2248     -0.0020      0.0085
# Cmp%           0.0717     0.0092     7.8224     0.0000      0.0537      0.0897
# Ast            0.1883     0.0226     8.3456     0.0000      0.1441      0.2325
# Tkl%          -0.0026     0.0030    -0.8787     0.3796     -0.0084      0.0032
# Clr            0.0124     0.0017     7.1821     0.0000      0.0090      0.0158
# Att.5          0.0169     0.0023     7.3237     0.0000      0.0124      0.0214
# Succ%      -2.838e-05     0.0025    -0.0115     0.9908     -0.0049      0.0048
# PPM            1.8771     0.1155     16.247     0.0000      1.6505      2.1036
# CrdY           0.0510     0.0204     2.4984     0.0125      0.0110      0.0911
# CrdR           0.0193     0.0985     0.1960     0.8446     -0.1738      0.2124
# Won%           0.0057     0.0036     1.5767     0.1150     -0.0014      0.0127
# def            16.531   1.73e+06  9.558e-06     1.0000  -3.392e+06   3.392e+06
# mid            16.970   1.73e+06  9.812e-06     1.0000  -3.392e+06   3.392e+06
# forw           16.747   1.73e+06  9.683e-06     1.0000  -3.392e+06   3.392e+06
# ==============================================================================
#
# Breusch-Pagan test for red group:
# LM statistic: 75.155648134631, p-value: 5.307012605042022e-10, f-value: 5.503443601385503, f_p-value: 1.5202936503840094e-10
# Heteroskedasticity detected for red group.
#
# Random Effects Regression Results for yellow group:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.2732
# Estimator:              RandomEffects   R-squared (Between):              0.4018
# No. Observations:                2464   R-squared (Within):               0.1743
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.3743
# Time:                        23:30:52   Log-likelihood                   -4981.1
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      65.748
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(14,2449)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             48.196
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(14,2449)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          56.350
# xG             0.2994     0.0211     14.210     0.0000      0.2581      0.3407
# Blocks         0.0092     0.0058     1.5885     0.1123     -0.0022      0.0205
# Tkl+Int        0.0088     0.0024     3.6383     0.0003      0.0041      0.0136
# Err            0.0899     0.0523     1.7198     0.0856     -0.0126      0.1925
# Def Pen        0.0063     0.0014     4.4770     0.0000      0.0036      0.0091
# Att.5          0.0133     0.0027     4.9285     0.0000      0.0080      0.0186
# Succ%          0.0012     0.0025     0.4821     0.6298     -0.0037      0.0061
# Mn/Sub         0.0065     0.0031     2.0966     0.0361      0.0004      0.0125
# xG+/-90        1.0392     0.0806     12.888     0.0000      0.8811      1.1973
# OG            -0.0699     0.1634    -0.4275     0.6690     -0.3902      0.2505
# Won%           0.0043     0.0037     1.1619     0.2454     -0.0030      0.0116
# def            18.825
# mid            18.910
# forw           18.616
# ==============================================================================
#
# Breusch-Pagan test for yellow group:
# LM statistic: 24.48620735693166, p-value: 0.03999169265770319, f-value: 1.8916508377580579, f_p-value: 0.026640579307921436
# Heteroskedasticity detected for yellow group.
#
# Random Effects Regression Results for green group:
#                         RandomEffects Estimation Summary
# ================================================================================
# Dep. Variable:                 RATING   R-squared:                        0.2792
# Estimator:              RandomEffects   R-squared (Between):              0.4242
# No. Observations:                2464   R-squared (Within):               0.1634
# Date:                Sun, Apr 09 2023   R-squared (Overall):              0.3926
# Time:                        23:30:52   Log-likelihood                   -4991.4
# Cov. Estimator:            Unadjusted
#                                         F-statistic:                      42.968
# Entities:                         616   P-value                           0.0000
# Avg Obs:                       4.0000   Distribution:                 F(22,2441)
# Min Obs:                       4.0000
# Max Obs:                       4.0000   F-statistic (robust):             45.203
#                                         P-value                           0.0000
# Time periods:                       4   Distribution:                 F(22,2441)
# Avg Obs:                       616.00
# Min Obs:                       616.00
# Max Obs:                       616.00
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# const          52.096
# Sh/90          0.4682     0.0755     6.2051     0.0000      0.3202      0.6161
# np:G-xG        0.2119     0.0270     7.8628     0.0000      0.1591      0.2648
# Dist          -0.0345     0.0110    -3.1394     0.0017     -0.0561     -0.0130
# npxG/Sh        4.5987     1.0841     4.2419     0.0000      2.4728      6.7246
# Cmp%           0.0788     0.0102     7.6992     0.0000      0.0588      0.0989
# A-xAG          0.1399     0.0309     4.5300     0.0000      0.0793      0.2004
# Crs            0.0123     0.0016     7.6952     0.0000      0.0091      0.0154
# TO             0.1319     0.0155     8.5061     0.0000      0.1015      0.1623
# Tkl%          -0.0066     0.0031    -2.1286     0.0334     -0.0127     -0.0005
# Tkl+Int        0.0139     0.0025     5.4540     0.0000      0.0089      0.0189
# Err            0.0677     0.0527     1.2848     0.1990     -0.0356      0.1711
# Def Pen        0.0073     0.0015     4.8027     0.0000      0.0043      0.0103
# Succ%         -0.0006     0.0025    -0.2368     0.8128     -0.0056      0.0044
# 44986          0.0069     0.0012     5.6807     0.0000      0.0045      0.0093
# onGA          -0.0171     0.0059    -2.8961     0.0038     -0.0287     -0.0055
# xG+/-90        0.6587     0.0942     6.9949     0.0000      0.4740      0.8433
# CrdY           0.0045     0.0231     0.1946     0.8457     -0.0408      0.0497
# CrdR          -0.0312     0.1013    -0.3079     0.7582     -0.2299      0.1675
# Won%           0.0049     0.0037     1.3188     0.1874     -0.0024      0.0122
# def            17.142
# mid            17.495
# forw           17.458
# ==============================================================================
#
# Breusch-Pagan test for green group:
# LM statistic: 138.5258072823733, p-value: 6.780719067694864e-19, f-value: 6.927005467220838, f_p-value: 6.139243267292854e-20
# Heteroskedasticity detected for green group.
